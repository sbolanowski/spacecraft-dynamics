# %%
# !pip install numpy sympy matplotlib scipy

import numpy as np
import sympy as sm
from sympy.physics.vector import *
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from scipy.integrate import solve_ivp
import utils
# utils.py
from utils import getPRVfromDCM, getPRVfromEuler, addPRVs, subPRVs, DCMfromQuaternion, quat_2_dcm

# %%
angles = np.radians([20, -10, 120])
e, phi = getPRVfromEuler(angles, '321')
print("Vector: {}\nphi: {} radians".format(e, phi))
# Out:
# Vector: [0.98308475 0.07889999 0.16528509]
# phi: -0.03719234596110638 radians

# %%
q = [0.235702,0.471405,-0.471405,0.707107]
quat_2_dcm(q)
# Out:
# array([[-0.44444488, -0.11111228,  0.88888975],
#        [-0.77777842, -0.44444488, -0.44444535],
#        [ 0.44444535, -0.88888975,  0.11111039]])

# %%
q = [0.235702,0.471405,-0.471405,0.707107]
DCMfromQuaternion(q)  ###### XXXXXX  wrong result
# Out:
# array([[-0.44444488, -0.11111228,  0.88888975],
#        [-0.11111228, -0.44444488, -0.44444535],
#        [ 0.88888975, -0.44444535,  0.11111039]])
